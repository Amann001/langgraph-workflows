# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(
    model="llama-3.3-70b-versatile"
)

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    #fetch title
    title = state['title']
    #call llm
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content
    #update state
    state['outline'] = outline
    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    title = state['title']
    outline = state['outline']
    prompt = f'Write a detailed blog on the title - {title} using the following outline \n {outline}'
    content = model.invoke(prompt).content
    state['content'] = content
    return state

# %%
graph = StateGraph(BlogState)

#adding nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)
#adding edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

#complile the graph
workflow = graph.compile()

# %%
#executing the graph
initial_state = {'title': 'RISE OF AI IN INDIA'}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'RISE OF AI IN INDIA', 'outline': 'Here\'s a detailed outline for a blog on the topic "Rise of AI in India":\n\n**I. Introduction**\n\n* Brief overview of Artificial Intelligence (AI) and its growing importance globally\n* Importance of AI in India\'s economic growth and development\n* Thesis statement: India is witnessing a significant rise in AI adoption, driven by government initiatives, technological advancements, and increasing demand for AI-powered solutions.\n\n**II. Current State of AI in India**\n\n* Overview of India\'s AI landscape, including key sectors such as:\n\t+ Healthcare\n\t+ Finance\n\t+ Education\n\t+ Manufacturing\n* Statistics on AI adoption in India, including:\n\t+ Number of AI startups\n\t+ AI-related job openings\n\t+ Investment in AI research and development\n* Key challenges facing AI adoption in India, including:\n\t+ Data quality and availability\n\t+ Talent shortage\n\t+ Regulatory framework\n\n**III. Government Initiatives and Policies**\n\n* Overview of government initiatives to promote AI adoption in India, including:\n\t+ National AI Strategy\n\t+ AI Task Force\n\t+ NITI Aayog\'s AI initiative\n* Discussion of key policies and regulations, including:\n\t+ Data Protection Bill\n\t+ AI-related tax incentives\n\t+ Intellectual Property (IP) protection for AI innovations\n* Examples of government-funded AI projects and initiatives, such as:\n\t+ AI-powered healthcare systems\n\t+ AI-driven smart cities\n\n**IV. Technological Advancements and Innovations**\n\n* Overview of technological advancements driving AI adoption in India, including:\n\t+ Cloud computing\n\t+ Internet of Things (IoT)\n\t+ Big Data analytics\n* Discussion of AI innovations in India, including:\n\t+ Natural Language Processing (NLP)\n\t+ Computer Vision\n\t+ Machine Learning (ML)\n* Examples of Indian startups and companies developing innovative AI solutions, such as:\n\t+ Chatbots for customer service\n\t+ AI-powered predictive maintenance\n\n**V. Applications and Use Cases**\n\n* Overview of AI applications in various industries, including:\n\t+ Healthcare: disease diagnosis, personalized medicine\n\t+ Finance: credit scoring, risk management\n\t+ Education: adaptive learning, student assessment\n\t+ Manufacturing: predictive maintenance, quality control\n* Examples of successful AI implementation in Indian companies, such as:\n\t+ Tata Consultancy Services (TCS) - AI-powered customer service\n\t+ HDFC Bank - AI-driven credit scoring\n\t+ Flipkart - AI-powered supply chain management\n\n**VI. Challenges and Limitations**\n\n* Discussion of challenges facing AI adoption in India, including:\n\t+ Data quality and availability\n\t+ Talent shortage\n\t+ Regulatory framework\n* Overview of limitations of AI, including:\n\t+ Bias and fairness\n\t+ Explainability and transparency\n\t+ Job displacement and societal impact\n\n**VII. Future Outlook and Opportunities**\n\n* Discussion of future opportunities for AI in India, including:\n\t+ Growing demand for AI-powered solutions\n\t+ Increasing investment in AI research and development\n\t+ Emerging applications in areas like agriculture and transportation\n* Overview of India\'s potential to become a global AI hub, including:\n\t+ Large talent pool\n\t+ Favorable business environment\n\t+ Government support and initiatives\n\n**VIII. Conclusion**\n\n* Recap of key points\n* Final thoughts on the rise of AI in India and its potential to drive economic growth and development\n* Call to action for stakeholders to work together to promote AI adoption and address challenges facing the industry.\n\nThis outline should provide a comprehensive framework for a blog on the topic "Rise of AI in India".', 'content': "**The Rise of AI in India: A New Era of Economic Growth and Development**\n\nArtificial Intelligence (AI) is transforming the world at an unprecedented pace, and India is no exception. With its growing importance in driving economic growth and development, AI has become a ...

# %%
print(final_state['outline'])
# Out:
# Here's a detailed outline for a blog on the topic "Rise of AI in India":
#
# **I. Introduction**
#
# * Brief overview of Artificial Intelligence (AI) and its growing importance globally
# * Importance of AI in India's economic growth and development
# * Thesis statement: India is witnessing a significant rise in AI adoption, driven by government initiatives, technological advancements, and increasing demand for AI-powered solutions.
#
# **II. Current State of AI in India**
#
# * Overview of India's AI landscape, including key sectors such as:
# 	+ Healthcare
# 	+ Finance
# 	+ Education
# 	+ Manufacturing
# * Statistics on AI adoption in India, including:
# 	+ Number of AI startups
# 	+ AI-related job openings
# 	+ Investment in AI research and development
# * Key challenges facing AI adoption in India, including:
# 	+ Data quality and availability
# 	+ Talent shortage
# 	+ Regulatory framework
#
# **III. Government Initiatives and Policies**
#
# * Overview of government initiatives to promote AI adoption in India, including:
# 	+ National AI Strategy
# 	+ AI Task Force
# 	+ NITI Aayog's AI initiative
# * Discussion of key policies and regulations, including:
# 	+ Data Protection Bill
# 	+ AI-related tax incentives
# 	+ Intellectual Property (IP) protection for AI innovations
# * Examples of government-funded AI projects and initiatives, such as:
# 	+ AI-powered healthcare systems
# 	+ AI-driven smart cities
#
# **IV. Technological Advancements and Innovations**
#
# * Overview of technological advancements driving AI adoption in India, including:
# 	+ Cloud computing
# 	+ Internet of Things (IoT)
# 	+ Big Data analytics
# * Discussion of AI innovations in India, including:
# 	+ Natural Language Processing (NLP)
# 	+ Computer Vision
# 	+ Machine Learning (ML)
# * Examples of Indian startups and companies developing innovative AI solutions, such as:
# 	+ Chatbots for customer service
# 	+ AI-powered predictive maintenance
#
# **V. Applications and Use Cases**
#
# * Overview of AI applications in various industries, including:
# 	+ Healthcare: disease diagnosis, personalized medicine
# 	+ Finance: credit scoring, risk management
# 	+ Education: adaptive learning, student assessment
# 	+ Manufacturing: predictive maintenance, quality control
# * Examples of successful AI implementation in Indian companies, such as:
# 	+ Tata Consultancy Services (TCS) - AI-powered customer service
# 	+ HDFC Bank - AI-driven credit scoring
# 	+ Flipkart - AI-powered supply chain management
#
# **VI. Challenges and Limitations**
#
# * Discussion of challenges facing AI adoption in India, including:
# 	+ Data quality and availability
# 	+ Talent shortage
# 	+ Regulatory framework
# * Overview of limitations of AI, including:
# 	+ Bias and fairness
# 	+ Explainability and transparency
# 	+ Job displacement and societal impact
#
# **VII. Future Outlook and Opportunities**
#
# * Discussion of future opportunities for AI in India, including:
# 	+ Growing demand for AI-powered solutions
# 	+ Increasing investment in AI research and development
# 	+ Emerging applications in areas like agriculture and transportation
# * Overview of India's potential to become a global AI hub, including:
# 	+ Large talent pool
# 	+ Favorable business environment
# 	+ Government support and initiatives
#
# **VIII. Conclusion**
#
# * Recap of key points
# * Final thoughts on the rise of AI in India and its potential to drive economic growth and development
# * Call to action for stakeholders to work together to promote AI adoption and address challenges facing the industry.
#
# This outline should provide a comprehensive framework for a blog on the topic "Rise of AI in India".
